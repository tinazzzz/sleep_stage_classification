# %% [markdown]
# # Preprocessing Pipeline for Sleep-EDF Dataset
#
# ---
#
#
# This pipeline performs the following tasks on the Sleep-EDF dataset:
#
# 1.   Load PSG EEG channels (Fpz-Cz & Pz-Oz) and hypnogram
# 2.   Apply a bandpass filter of 0.3-35 Hz
# 3.   Epoch EEG signals into 30s segments
# 4.   Map stages to labels
# 5.   Align labels to epochs
# 6.   Drop movement/unwanted data
# 7.   Save preprocessed data into .npy files
#
#
#
# ---
#
#
#
# The preprocessed output consists of 2 numpy arrays:
#
#
# *   X - EEG inputs
# *   Y - labels

# %% [markdown]
# # Import + define stages-label map

# %%
import os
import glob
import numpy as np
import mne

# Sleep stage to label mapping
stage_map = {
    'Sleep stage W': 0,
    'Sleep stage 1': 1,
    'Sleep stage 2': 2,
    'Sleep stage 3': 3,
    'Sleep stage 4': 3,  # combine 3 + 4 into N3
    'Sleep stage R': 4,
    'Sleep stage M': -1,  # drop
    'Sleep stage ?': -1   # drop
}

# %% [markdown]
# # Fetch PSG + hypnogram files

# %%
data_dir = "/raw_data/"

psg_files = sorted(glob.glob(data_dir + "/physionet.org/files/sleep-edfx/1.0.0/sleep-cassette/*PSG.edf"))
hyp_files = sorted(glob.glob(data_dir + "/physionet.org/files/sleep-edfx/1.0.0/sleep-cassette/*Hypnogram.edf"))

print("PSG:", len(psg_files), "Hypnograms:", len(hyp_files))
# Out:
# Mounted at /content/drive
# PSG: 153 Hypnograms: 153

# %% [markdown]
# # Match PSG-hypnogram pairs

# %%
pairs = []

for psg in psg_files:
    base = os.path.basename(psg).split("-")[0][:6]  # e.g. SC4031
    match = [h for h in hyp_files if base in h]
    if match:
        pairs.append((psg, match[0]))

print("Matched pairs:", len(pairs))
# Out:
# Matched pairs: 153

# %% [markdown]
# # Main preprocessing function

# %%
def preprocess_recording(psg_path, hyp_path, epoch_length=30):
    """Preprocess one Sleep Cassette PSG + Hypnogram into CNN-ready X, y."""

    # --------------------------
    # 1. Read PSG (EEGs)
    # --------------------------
    raw = mne.io.read_raw_edf(psg_path, preload=True)

    # Extract EEG channels recommended in documentation
    available = raw.ch_names
    eeg_channels = [ch for ch in ["EEG Fpz-Cz", "EEG Pz-Oz"] if ch in available]

    if len(eeg_channels) == 0:
        raise ValueError("EEG channels missing from file:", psg_path)

    raw.pick_channels(eeg_channels)

    # Bandpass filter 0.3–35 Hz (sleep scoring standard)
    raw.filter(0.3, 35., fir_design="firwin")

    # --------------------------
    # 2. Read HYPNOGRAM
    # --------------------------
    annots = mne.read_annotations(hyp_path)
    raw.set_annotations(annots)

    # Map sleep stages to label indices
    events, event_ids = mne.events_from_annotations(raw, event_id=stage_map)

    # --------------------------
    # 3. Split eeg into 30s epochs
    # --------------------------
    epochs = mne.make_fixed_length_epochs(raw,
                                          duration=epoch_length,
                                          preload=True)

    X = epochs.get_data()  # shape: (n_epochs, channels, samples)

    # --------------------------
    # 4. ASSIGN STAGE LABEL TO EACH EPOCH
    # --------------------------
    y = []

    for start in epochs.events[:, 0] / raw.info['sfreq']:
        # Find annotation whose time window covers this epoch start
        match = None
        for annot in annots:
            if annot['onset'] <= start < annot['onset'] + annot['duration']:
                match = annot['description']
                break

        if match is None:
            y.append(-1)
        else:
            y.append(stage_map.get(match, -1))

    y = np.array(y)

    # --------------------------
    # 5. Drop invalid epochs (Movement, ?)
    # --------------------------
    valid = y != -1
    X = X[valid]
    y = y[valid]

    return X, y

# %% [markdown]
# (Optional) Make some logs from MNE silent

# %%
import warnings

mne.set_log_level('WARNING')
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# # Run preprocessing for each Cassette subject

# %%
import gc
import numpy as np

save_dir = "/content/processed_sc"
os.makedirs(save_dir, exist_ok=True)

for i, (psg, hyp) in enumerate(pairs):
    print(f"Processing file {i+1}/{len(pairs)}: {os.path.basename(psg)}")
    X, y = preprocess_recording(psg, hyp)

    print("  Shapes:", X.shape, y.shape)
    print("  Channels:", X.shape[1])
    print("  Samples per epoch:", X.shape[2])
    print("  Unique labels:", np.unique(y))

    # Show small data snippet
    print("  First label:", y[0])
    print("  First epoch (first 3 samples):", X[0, 0, :3])
    print("  ----------------------------------")

    # Save EACH SUBJECT separately
    np.save(f"{save_dir}/X_{i}.npy", X)
    np.save(f"{save_dir}/y_{i}.npy", y)
    print(f"  Saved X_{i}.npy and y_{i}.npy")

    # CLEAR RAM
    del X, y
    gc.collect()
# Out:
# Processing file 1/153: SC4001E0-PSG.edf
#   Shapes: (2650, 2, 3000) (2650,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 2.03287907e-20 -7.12998692e-06 -4.31699508e-06]
#   ----------------------------------
#   Saved X_0.npy and y_0.npy
# Processing file 2/153: SC4002E0-PSG.edf
#   Shapes: (2829, 2, 3000) (2829,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [3.38813179e-21 3.68525224e-05 2.13092512e-05]
#   ----------------------------------
#   Saved X_1.npy and y_1.npy
# Processing file 3/153: SC4011E0-PSG.edf
#   Shapes: (2802, 2, 3000) (2802,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 3.26107685e-20 -4.79873198e-06 -5.56032260e-06]
#   ----------------------------------
#   Saved X_2.npy and y_2.npy
# Processing file 4/153: SC4012E0-PSG.edf
#   Shapes: (2848, 2, 3000) (2848,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [5.92923063e-21 1.10461758e-05 2.22960209e-05]
#   ----------------------------------
#   Saved X_3.npy and y_3.npy
# Processing file 5/153: SC4021E0-PSG.edf
#   Shapes: (2804, 2, 3000) (2804,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-3.38813179e-21 -3.40074018e-06 -5.15942665e-06]
#   ----------------------------------
#   Saved X_4.npy and y_4.npy
# Processing file 6/153: SC4022E0-PSG.edf
#   Shapes: (2755, 2, 3000) (2755,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.35525272e-20 -1.14416008e-06 -3.61838887e-06]
#   ----------------------------------
#   Saved X_5.npy and y_5.npy
# Processing file 7/153: SC4031E0-PSG.edf
#   Shapes: (2820, 2, 3000) (2820,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 1.69406589e-20 -7.03835635e-06 -1.44609282e-06]
#   ----------------------------------
#   Saved X_6.npy and y_6.npy
# Processing file 8/153: SC4032E0-PSG.edf
#   Shapes: (2732, 2, 3000) (2732,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.18584613e-20 -1.50980757e-05 -1.97591061e-06]
#   ----------------------------------
#   Saved X_7.npy and y_7.npy
# Processing file 9/153: SC4041E0-PSG.edf
#   Shapes: (2569, 2, 3000) (2569,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.01643954e-20 -9.46656001e-06 -1.20748568e-05]
#   ----------------------------------
#   Saved X_8.npy and y_8.npy
# Processing file 10/153: SC4042E0-PSG.edf
#   Shapes: (2788, 2, 3000) (2788,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-3.38813179e-21 -1.26008865e-05 -1.16539375e-05]
#   ----------------------------------
#   Saved X_9.npy and y_9.npy
# Processing file 11/153: SC4051E0-PSG.edf
#   Shapes: (2722, 2, 3000) (2722,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 7.62329653e-21 -4.33290352e-06  1.95023722e-07]
#   ----------------------------------
#   Saved X_10.npy and y_10.npy
# Processing file 12/153: SC4052E0-PSG.edf
#   Shapes: (2804, 2, 3000) (2804,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [0.00000000e+00 7.97410220e-06 3.36240343e-06]
#   ----------------------------------
#   Saved X_11.npy and y_11.npy
# Processing file 13/153: SC4061E0-PSG.edf
#   Shapes: (2770, 2, 3000) (2770,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [0.00000000e+00 2.76407182e-06 9.42054384e-06]
#   ----------------------------------
#   Saved X_12.npy and y_12.npy
# Processing file 14/153: SC4062E0-PSG.edf
#   Shapes: (2830, 2, 3000) (2830,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-5.08219768e-21 -6.65260254e-06  1.50055205e-05]
#   ----------------------------------
#   Saved X_13.npy and y_13.npy
# Processing file 15/153: SC4071E0-PSG.edf
#   Shapes: (2810, 2, 3000) (2810,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [7.19978005e-21 1.08104938e-06 9.51258525e-06]
#   ----------------------------------
#   Saved X_14.npy and y_14.npy
# Processing file 16/153: SC4072E0-PSG.edf
#   Shapes: (2770, 2, 3000) (2770,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 6.77626358e-21 -8.50928226e-06  4.56543853e-06]
#   ----------------------------------
#   Saved X_15.npy and y_15.npy
# Processing file 17/153: SC4081E0-PSG.edf
#   Shapes: (2796, 2, 3000) (2796,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [5.08219768e-21 5.06143132e-06 1.23600389e-05]
#   ----------------------------------
#   Saved X_16.npy and y_16.npy
# Processing file 18/153: SC4082E0-PSG.edf
#   Shapes: (2634, 2, 3000) (2634,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [4.15046144e-20 4.10585801e-06 2.80274929e-06]
#   ----------------------------------
#   Saved X_17.npy and y_17.npy
# Processing file 19/153: SC4091E0-PSG.edf
#   Shapes: (2721, 2, 3000) (2721,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [1.69406589e-21 1.21579848e-05 1.43861427e-05]
#   ----------------------------------
#   Saved X_18.npy and y_18.npy
# Processing file 20/153: SC4092E0-PSG.edf
#   Shapes: (2044, 2, 3000) (2044,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-4.74338450e-20  1.82546288e-05  2.34912025e-05]
#   ----------------------------------
#   Saved X_19.npy and y_19.npy
# Processing file 21/153: SC4101E0-PSG.edf
#   Shapes: (2719, 2, 3000) (2719,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 0.00000000e+00  1.22068271e-06 -9.56245204e-07]
#   ----------------------------------
#   Saved X_20.npy and y_20.npy
# Processing file 22/153: SC4102E0-PSG.edf
#   Shapes: (2857, 2, 3000) (2857,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 3.38813179e-21 -3.09604561e-06 -3.01062075e-06]
#   ----------------------------------
#   Saved X_21.npy and y_21.npy
# Processing file 23/153: SC4111E0-PSG.edf
#   Shapes: (2641, 2, 3000) (2641,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-3.38813179e-21 -1.96399062e-06 -3.08440483e-06]
#   ----------------------------------
#   Saved X_22.npy and y_22.npy
# Processing file 24/153: SC4112E0-PSG.edf
#   Shapes: (2780, 2, 3000) (2780,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-2.11758237e-21 -2.56052485e-06 -1.57332653e-05]
#   ----------------------------------
#   Saved X_23.npy and y_23.npy
# Processing file 25/153: SC4121E0-PSG.edf
#   Shapes: (2685, 2, 3000) (2685,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [1.01643954e-20 2.50568745e-06 4.05708990e-08]
#   ----------------------------------
#   Saved X_24.npy and y_24.npy
# Processing file 26/153: SC4122E0-PSG.edf
#   Shapes: (2606, 2, 3000) (2606,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-5.08219768e-21  8.89038134e-06  3.56436654e-06]
#   ----------------------------------
#   Saved X_25.npy and y_25.npy
# Processing file 27/153: SC4131E0-PSG.edf
#   Shapes: (2814, 2, 3000) (2814,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 2.37169225e-20  1.47492577e-06 -1.01043744e-05]
#   ----------------------------------
#   Saved X_26.npy and y_26.npy
# Processing file 28/153: SC4141E0-PSG.edf
#   Shapes: (2756, 2, 3000) (2756,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.10114283e-20 -8.61564531e-06 -1.85752817e-05]
#   ----------------------------------
#   Saved X_27.npy and y_27.npy
# Processing file 29/153: SC4142E0-PSG.edf
#   Shapes: (2774, 2, 3000) (2774,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 1.69406589e-21  4.55000747e-06 -3.01144846e-06]
#   ----------------------------------
#   Saved X_28.npy and y_28.npy
# Processing file 30/153: SC4151E0-PSG.edf
#   Shapes: (2616, 2, 3000) (2616,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [5.92923063e-21 1.49047814e-06 3.14507997e-07]
#   ----------------------------------
#   Saved X_29.npy and y_29.npy
# Processing file 31/153: SC4152E0-PSG.edf
#   Shapes: (2859, 2, 3000) (2859,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 0.00000000e+00  1.22978121e-06 -2.43820147e-06]
#   ----------------------------------
#   Saved X_30.npy and y_30.npy
# Processing file 32/153: SC4161E0-PSG.edf
#   Shapes: (2621, 2, 3000) (2621,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.01643954e-20  7.20265191e-06  9.02493066e-06]
#   ----------------------------------
#   Saved X_31.npy and y_31.npy
# Processing file 33/153: SC4162E0-PSG.edf
#   Shapes: (2750, 2, 3000) (2750,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 5.08219768e-21 -1.66401186e-05 -1.75155203e-05]
#   ----------------------------------
#   Saved X_32.npy and y_32.npy
# Processing file 34/153: SC4171E0-PSG.edf
#   Shapes: (2741, 2, 3000) (2741,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [6.77626358e-21 5.24781556e-06 4.29560733e-06]
#   ----------------------------------
#   Saved X_33.npy and y_33.npy
# Processing file 35/153: SC4172E0-PSG.edf
#   Shapes: (2720, 2, 3000) (2720,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-5.29395592e-21  1.33709834e-05  1.55523700e-05]
#   ----------------------------------
#   Saved X_34.npy and y_34.npy
# Processing file 36/153: SC4181E0-PSG.edf
#   Shapes: (2756, 2, 3000) (2756,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 6.77626358e-21 -5.20284975e-06 -4.58169449e-06]
#   ----------------------------------
#   Saved X_35.npy and y_35.npy
# Processing file 37/153: SC4182E0-PSG.edf
#   Shapes: (2842, 2, 3000) (2842,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.35525272e-20 -1.62512750e-05 -1.41086552e-05]
#   ----------------------------------
#   Saved X_36.npy and y_36.npy
# Processing file 38/153: SC4191E0-PSG.edf
#   Shapes: (2774, 2, 3000) (2774,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [0.00000000e+00 7.63342983e-06 1.00262915e-05]
#   ----------------------------------
#   Saved X_37.npy and y_37.npy
# Processing file 39/153: SC4192E0-PSG.edf
#   Shapes: (2605, 2, 3000) (2605,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 1.27054942e-20 -8.34616103e-06  7.71365781e-06]
#   ----------------------------------
#   Saved X_38.npy and y_38.npy
# Processing file 40/153: SC4201E0-PSG.edf
#   Shapes: (2803, 2, 3000) (2803,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.35525272e-20  1.41953705e-05 -3.52331130e-06]
#   ----------------------------------
#   Saved X_39.npy and y_39.npy
# Processing file 41/153: SC4202E0-PSG.edf
#   Shapes: (2670, 2, 3000) (2670,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [-6.77626358e-21  2.82786948e-06 -5.20607684e-07]
#   ----------------------------------
#   Saved X_40.npy and y_40.npy
# Processing file 42/153: SC4211E0-PSG.edf
#   Shapes: (2805, 2, 3000) (2805,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 6.77626358e-21 -1.10815350e-05 -8.59839520e-06]
#   ----------------------------------
#   Saved X_41.npy and y_41.npy
# Processing file 43/153: SC4212E0-PSG.edf
#   Shapes: (2694, 2, 3000) (2694,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.35525272e-20  2.66438097e-07  5.43815863e-06]
#   ----------------------------------
#   Saved X_42.npy and y_42.npy
# Processing file 44/153: SC4221E0-PSG.edf
#   Shapes: (2700, 2, 3000) (2700,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 2.03287907e-20 -1.21770830e-05  4.64367609e-06]
#   ----------------------------------
#   Saved X_43.npy and y_43.npy
# Processing file 45/153: SC4222E0-PSG.edf
#   Shapes: (2760, 2, 3000) (2760,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.69406589e-20  1.99796505e-05  3.63623468e-05]
#   ----------------------------------
#   Saved X_44.npy and y_44.npy
# Processing file 46/153: SC4231E0-PSG.edf
#   Shapes: (2743, 2, 3000) (2743,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [3.38813179e-21 3.94609237e-06 4.70367416e-06]
#   ----------------------------------
#   Saved X_45.npy and y_45.npy
# Processing file 47/153: SC4232E0-PSG.edf
#   Shapes: (2635, 2, 3000) (2635,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [1.13290657e-20 1.98621596e-06 1.00777093e-07]
#   ----------------------------------
#   Saved X_46.npy and y_46.npy
# Processing file 48/153: SC4241E0-PSG.edf
#   Shapes: (2700, 2, 3000) (2700,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-6.77626358e-21  8.82616291e-06  6.39544757e-07]
#   ----------------------------------
#   Saved X_47.npy and y_47.npy
# Processing file 49/153: SC4242E0-PSG.edf
#   Shapes: (2710, 2, 3000) (2710,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 5.08219768e-21  6.76123463e-05 -2.08235667e-05]
#   ----------------------------------
#   Saved X_48.npy and y_48.npy
# Processing file 50/153: SC4251E0-PSG.edf
#   Shapes: (2760, 2, 3000) (2760,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-2.03287907e-20  3.47830811e-07 -1.39472206e-05]
#   ----------------------------------
#   Saved X_49.npy and y_49.npy
# Processing file 51/153: SC4252E0-PSG.edf
#   Shapes: (2665, 2, 3000) (2665,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 6.35274710e-21 -2.42132794e-05 -3.12711730e-05]
#   ----------------------------------
#   Saved X_50.npy and y_50.npy
# Processing file 52/153: SC4261F0-PSG.edf
#   Shapes: (2800, 2, 3000) (2800,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 8.47032947e-21 -7.67061454e-06 -4.86043895e-06]
#   ----------------------------------
#   Saved X_51.npy and y_51.npy
# Processing file 53/153: SC4262F0-PSG.edf
#   Shapes: (2720, 2, 3000) (2720,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-6.77626358e-21  1.96118793e-05  1.57975141e-05]
#   ----------------------------------
#   Saved X_52.npy and y_52.npy
# Processing file 54/153: SC4271F0-PSG.edf
#   Shapes: (2440, 2, 3000) (2440,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-5.08219768e-21  9.80493367e-06  2.05782074e-07]
#   ----------------------------------
#   Saved X_53.npy and y_53.npy
# Processing file 55/153: SC4272F0-PSG.edf
#   Shapes: (2870, 2, 3000) (2870,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 9.31736242e-21 -1.74871762e-06  2.21830487e-07]
#   ----------------------------------
#   Saved X_54.npy and y_54.npy
# Processing file 56/153: SC4281G0-PSG.edf
#   Shapes: (2788, 2, 3000) (2788,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 6.77626358e-21 -4.50847355e-07  1.70629896e-06]
#   ----------------------------------
#   Saved X_55.npy and y_55.npy
# Processing file 57/153: SC4282G0-PSG.edf
#   Shapes: (2814, 2, 3000) (2814,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [3.38813179e-21 5.52366949e-06 8.41366476e-06]
#   ----------------------------------
#   Saved X_56.npy and y_56.npy
# Processing file 58/153: SC4291G0-PSG.edf
#   Shapes: (2756, 2, 3000) (2756,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 6.77626358e-21 -7.90407815e-06 -1.58521866e-05]
#   ----------------------------------
#   Saved X_57.npy and y_57.npy
# Processing file 59/153: SC4292G0-PSG.edf
#   Shapes: (2807, 2, 3000) (2807,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 9.31736242e-21 -1.34975426e-05 -7.88475184e-06]
#   ----------------------------------
#   Saved X_58.npy and y_58.npy
# Processing file 60/153: SC4301E0-PSG.edf
#   Shapes: (2644, 2, 3000) (2644,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [1.05879118e-21 1.65176118e-06 6.14635187e-06]
#   ----------------------------------
#   Saved X_59.npy and y_59.npy
# Processing file 61/153: SC4302E0-PSG.edf
#   Shapes: (2808, 2, 3000) (2808,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [1.05879118e-21 3.87803744e-06 2.56399523e-06]
#   ----------------------------------
#   Saved X_60.npy and y_60.npy
# Processing file 62/153: SC4311E0-PSG.edf
#   Shapes: (2670, 2, 3000) (2670,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.69406589e-20 -1.68001149e-05 -4.95469619e-06]
#   ----------------------------------
#   Saved X_61.npy and y_61.npy
# Processing file 63/153: SC4312E0-PSG.edf
#   Shapes: (2700, 2, 3000) (2700,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-8.89384595e-21  2.42502775e-05  4.28417417e-05]
#   ----------------------------------
#   Saved X_62.npy and y_62.npy
# Processing file 64/153: SC4321E0-PSG.edf
#   Shapes: (2689, 2, 3000) (2689,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [ 6.77626358e-21  9.77077903e-06 -2.80419755e-06]
#   ----------------------------------
#   Saved X_63.npy and y_63.npy
# Processing file 65/153: SC4322E0-PSG.edf
#   Shapes: (2616, 2, 3000) (2616,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.60936260e-20  1.76217928e-07 -3.11699878e-06]
#   ----------------------------------
#   Saved X_64.npy and y_64.npy
# Processing file 66/153: SC4331F0-PSG.edf
#   Shapes: (2809, 2, 3000) (2809,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [ 2.03287907e-20 -1.96664767e-06 -8.03748914e-07]
#   ----------------------------------
#   Saved X_65.npy and y_65.npy
# Processing file 67/153: SC4332F0-PSG.edf
#   Shapes: (2758, 2, 3000) (2758,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [3.38813179e-21 1.51606857e-05 1.43104745e-05]
#   ----------------------------------
#   Saved X_66.npy and y_66.npy
# Processing file 68/153: SC4341F0-PSG.edf
#   Shapes: (2750, 2, 3000) (2750,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [6.77626358e-21 1.46318138e-06 2.37104170e-06]
#   ----------------------------------
#   Saved X_67.npy and y_67.npy
# Processing file 69/153: SC4342F0-PSG.edf
#   Shapes: (2790, 2, 3000) (2790,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.01643954e-20 -1.90308768e-07 -4.67694456e-07]
#   ----------------------------------
#   Saved X_68.npy and y_68.npy
# Processing file 70/153: SC4351F0-PSG.edf
#   Shapes: (2710, 2, 3000) (2710,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 0.00000000e+00 -3.25041228e-06 -3.87410858e-06]
#   ----------------------------------
#   Saved X_69.npy and y_69.npy
# Processing file 71/153: SC4352F0-PSG.edf
#   Shapes: (2530, 2, 3000) (2530,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-3.81164826e-21  7.52045206e-06  6.10654392e-06]
#   ----------------------------------
#   Saved X_70.npy and y_70.npy
# Processing file 72/153: SC4362F0-PSG.edf
#   Shapes: (2266, 2, 3000) (2266,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [0.00000000e+00 4.63592674e-06 3.06885381e-06]
#   ----------------------------------
#   Saved X_71.npy and y_71.npy
# Processing file 73/153: SC4371F0-PSG.edf
#   Shapes: (2850, 2, 3000) (2850,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-6.77626358e-21 -2.89674387e-06 -1.74278442e-06]
#   ----------------------------------
#   Saved X_72.npy and y_72.npy
# Processing file 74/153: SC4372F0-PSG.edf
#   Shapes: (2840, 2, 3000) (2840,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 1.71524172e-20 -7.75888613e-07  2.37280187e-06]
#   ----------------------------------
#   Saved X_73.npy and y_73.npy
# Processing file 75/153: SC4381F0-PSG.edf
#   Shapes: (2750, 2, 3000) (2750,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [1.01643954e-20 1.20227200e-05 1.07450666e-06]
#   ----------------------------------
#   Saved X_74.npy and y_74.npy
# Processing file 76/153: SC4382F0-PSG.edf
#   Shapes: (2770, 2, 3000) (2770,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-2.54109884e-21 -6.91320393e-06 -9.58987194e-06]
#   ----------------------------------
#   Saved X_75.npy and y_75.npy
# Processing file 77/153: SC4401E0-PSG.edf
#   Shapes: (2630, 2, 3000) (2630,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-3.38813179e-21  1.56474505e-05  3.77633010e-05]
#   ----------------------------------
#   Saved X_76.npy and y_76.npy
# Processing file 78/153: SC4402E0-PSG.edf
#   Shapes: (2790, 2, 3000) (2790,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 2.71050543e-20 -1.54745761e-05 -6.86674328e-06]
#   ----------------------------------
#   Saved X_77.npy and y_77.npy
# Processing file 79/153: SC4411E0-PSG.edf
#   Shapes: (2728, 2, 3000) (2728,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 2.03287907e-20 -1.42158097e-05  2.70975130e-06]
#   ----------------------------------
#   Saved X_78.npy and y_78.npy
# Processing file 80/153: SC4412E0-PSG.edf
#   Shapes: (2765, 2, 3000) (2765,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [0.00000000e+00 6.54324897e-06 2.36199209e-05]
#   ----------------------------------
#   Saved X_79.npy and y_79.npy
# Processing file 81/153: SC4421E0-PSG.edf
#   Shapes: (2764, 2, 3000) (2764,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-8.47032947e-21 -6.34911635e-06 -1.03653895e-05]
#   ----------------------------------
#   Saved X_80.npy and y_80.npy
# Processing file 82/153: SC4422E0-PSG.edf
#   Shapes: (2682, 2, 3000) (2682,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [0.00000000e+00 3.42697184e-06 5.26478375e-06]
#   ----------------------------------
#   Saved X_81.npy and y_81.npy
# Processing file 83/153: SC4431E0-PSG.edf
#   Shapes: (2723, 2, 3000) (2723,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [0.00000000e+00 7.04701463e-06 1.24974202e-05]
#   ----------------------------------
#   Saved X_82.npy and y_82.npy
# Processing file 84/153: SC4432E0-PSG.edf
#   Shapes: (2780, 2, 3000) (2780,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [1.01643954e-20 6.48433279e-06 9.57760098e-06]
#   ----------------------------------
#   Saved X_83.npy and y_83.npy
# Processing file 85/153: SC4441E0-PSG.edf
#   Shapes: (2620, 2, 3000) (2620,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-3.04931861e-20  1.04481248e-06  2.67292512e-06]
#   ----------------------------------
#   Saved X_84.npy and y_84.npy
# Processing file 86/153: SC4442E0-PSG.edf
#   Shapes: (2778, 2, 3000) (2778,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.69406589e-20  6.06454817e-06  1.44442797e-05]
#   ----------------------------------
#   Saved X_85.npy and y_85.npy
# Processing file 87/153: SC4451F0-PSG.edf
#   Shapes: (2790, 2, 3000) (2790,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 5.29395592e-22  2.27467279e-06 -6.06477423e-06]
#   ----------------------------------
#   Saved X_86.npy and y_86.npy
# Processing file 88/153: SC4452F0-PSG.edf
#   Shapes: (2670, 2, 3000) (2670,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 1.18584613e-20 -2.24628323e-06 -5.93693977e-06]
#   ----------------------------------
#   Saved X_87.npy and y_87.npy
# Processing file 89/153: SC4461F0-PSG.edf
#   Shapes: (2695, 2, 3000) (2695,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 5.08219768e-21  8.47340331e-07 -5.54691687e-06]
#   ----------------------------------
#   Saved X_88.npy and y_88.npy
# Processing file 90/153: SC4462F0-PSG.edf
#   Shapes: (2854, 2, 3000) (2854,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.18584613e-20  2.20561726e-06  7.79093342e-06]
#   ----------------------------------
#   Saved X_89.npy and y_89.npy
# Processing file 91/153: SC4471F0-PSG.edf
#   Shapes: (2739, 2, 3000) (2739,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [1.01643954e-20 1.26093966e-05 6.67324932e-06]
#   ----------------------------------
#   Saved X_90.npy and y_90.npy
# Processing file 92/153: SC4472F0-PSG.edf
#   Shapes: (2789, 2, 3000) (2789,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-8.47032947e-21 -9.80547513e-06 -9.71887957e-06]
#   ----------------------------------
#   Saved X_91.npy and y_91.npy
# Processing file 93/153: SC4481F0-PSG.edf
#   Shapes: (2880, 2, 3000) (2880,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [1.27054942e-21 4.78735193e-06 1.03590312e-05]
#   ----------------------------------
#   Saved X_92.npy and y_92.npy
# Processing file 94/153: SC4482F0-PSG.edf
#   Shapes: (2880, 2, 3000) (2880,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 1.01643954e-20 -1.50571950e-05 -1.97922451e-05]
#   ----------------------------------
#   Saved X_93.npy and y_93.npy
# Processing file 95/153: SC4491G0-PSG.edf
#   Shapes: (2800, 2, 3000) (2800,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [3.38813179e-21 1.04740578e-05 7.57168882e-06]
#   ----------------------------------
#   Saved X_94.npy and y_94.npy
# Processing file 96/153: SC4492G0-PSG.edf
#   Shapes: (2135, 2, 3000) (2135,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-2.71050543e-20  1.88105362e-06  4.53078440e-07]
#   ----------------------------------
#   Saved X_95.npy and y_95.npy
# Processing file 97/153: SC4501E0-PSG.edf
#   Shapes: (2750, 2, 3000) (2750,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-8.47032947e-22  2.95195092e-06 -1.07128290e-06]
#   ----------------------------------
#   Saved X_96.npy and y_96.npy
# Processing file 98/153: SC4502E0-PSG.edf
#   Shapes: (2770, 2, 3000) (2770,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [2.03287907e-20 4.85249848e-05 5.21910584e-05]
#   ----------------------------------
#   Saved X_97.npy and y_97.npy
# Processing file 99/153: SC4511E0-PSG.edf
#   Shapes: (2712, 2, 3000) (2712,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-7.19978005e-21  1.41385450e-05  2.31030857e-06]
#   ----------------------------------
#   Saved X_98.npy and y_98.npy
# Processing file 100/153: SC4512E0-PSG.edf
#   Shapes: (2750, 2, 3000) (2750,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [5.08219768e-21 1.08221217e-05 7.02724036e-06]
#   ----------------------------------
#   Saved X_99.npy and y_99.npy
# Processing file 101/153: SC4522E0-PSG.edf
#   Shapes: (2774, 2, 3000) (2774,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 3.38813179e-21 -2.14642542e-06  3.93455063e-07]
#   ----------------------------------
#   Saved X_100.npy and y_100.npy
# Processing file 102/153: SC4531E0-PSG.edf
#   Shapes: (2602, 2, 3000) (2602,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-2.71050543e-20  9.48840354e-07  4.19477786e-06]
#   ----------------------------------
#   Saved X_101.npy and y_101.npy
# Processing file 103/153: SC4532E0-PSG.edf
#   Shapes: (2744, 2, 3000) (2744,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [4.57397792e-20 7.51289242e-07 1.23591499e-06]
#   ----------------------------------
#   Saved X_102.npy and y_102.npy
# Processing file 104/153: SC4541F0-PSG.edf
#   Shapes: (2739, 2, 3000) (2739,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 1.60936260e-20 -9.68363649e-05 -4.69579249e-05]
#   ----------------------------------
#   Saved X_103.npy and y_103.npy
# Processing file 105/153: SC4542F0-PSG.edf
#   Shapes: (2680, 2, 3000) (2680,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [6.77626358e-21 2.31372897e-05 2.92176623e-05]
#   ----------------------------------
#   Saved X_104.npy and y_104.npy
# Processing file 106/153: SC4551F0-PSG.edf
#   Shapes: (2772, 2, 3000) (2772,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.31290107e-20  1.00930936e-05  1.19103104e-05]
#   ----------------------------------
#   Saved X_105.npy and y_105.npy
# Processing file 107/153: SC4552F0-PSG.edf
#   Shapes: (2810, 2, 3000) (2810,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-4.23516474e-21 -3.73255724e-06 -2.70419370e-06]
#   ----------------------------------
#   Saved X_106.npy and y_106.npy
# Processing file 108/153: SC4561F0-PSG.edf
#   Shapes: (2702, 2, 3000) (2702,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [1.35525272e-20 4.90187913e-06 9.24813386e-07]
#   ----------------------------------
#   Saved X_107.npy and y_107.npy
# Processing file 109/153: SC4562F0-PSG.edf
#   Shapes: (2800, 2, 3000) (2800,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 2.71050543e-20 -3.50618256e-05 -2.33745679e-05]
#   ----------------------------------
#   Saved X_108.npy and y_108.npy
# Processing file 110/153: SC4571F0-PSG.edf
#   Shapes: (2836, 2, 3000) (2836,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.43995601e-20  1.71308002e-05  4.92103675e-06]
#   ----------------------------------
#   Saved X_109.npy and y_109.npy
# Processing file 111/153: SC4572F0-PSG.edf
#   Shapes: (2873, 2, 3000) (2873,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-6.77626358e-21  6.57480620e-06  1.33282839e-05]
#   ----------------------------------
#   Saved X_110.npy and y_110.npy
# Processing file 112/153: SC4581G0-PSG.edf
#   Shapes: (2738, 2, 3000) (2738,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-2.71050543e-20  5.67604299e-05  3.82274666e-05]
#   ----------------------------------
#   Saved X_111.npy and y_111.npy
# Processing file 113/153: SC4582G0-PSG.edf
#   Shapes: (2634, 2, 3000) (2634,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-3.38813179e-21  6.84980726e-05  3.95726642e-05]
#   ----------------------------------
#   Saved X_112.npy and y_112.npy
# Processing file 114/153: SC4591G0-PSG.edf
#   Shapes: (2819, 2, 3000) (2819,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 1.69406589e-20 -4.31775332e-06 -9.84854579e-07]
#   ----------------------------------
#   Saved X_113.npy and y_113.npy
# Processing file 115/153: SC4592G0-PSG.edf
#   Shapes: (2040, 2, 3000) (2040,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 1.69406589e-21 -6.70274986e-06 -1.47091869e-06]
#   ----------------------------------
#   Saved X_114.npy and y_114.npy
# Processing file 116/153: SC4601E0-PSG.edf
#   Shapes: (2730, 2, 3000) (2730,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [2.54109884e-21 8.09839651e-06 4.14175011e-06]
#   ----------------------------------
#   Saved X_115.npy and y_115.npy
# Processing file 117/153: SC4602E0-PSG.edf
#   Shapes: (2800, 2, 3000) (2800,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [9.74087889e-21 1.87901583e-06 3.56277994e-07]
#   ----------------------------------
#   Saved X_116.npy and y_116.npy
# Processing file 118/153: SC4611E0-PSG.edf
#   Shapes: (2644, 2, 3000) (2644,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-5.08219768e-21  6.66556673e-06  1.52441488e-06]
#   ----------------------------------
#   Saved X_117.npy and y_117.npy
# Processing file 119/153: SC4612E0-PSG.edf
#   Shapes: (2730, 2, 3000) (2730,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-5.08219768e-21 -2.80864595e-06  1.12869811e-06]
#   ----------------------------------
#   Saved X_118.npy and y_118.npy
# Processing file 120/153: SC4621E0-PSG.edf
#   Shapes: (2612, 2, 3000) (2612,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 1.27054942e-20 -3.06372256e-06  7.87917668e-06]
#   ----------------------------------
#   Saved X_119.npy and y_119.npy
# Processing file 121/153: SC4622E0-PSG.edf
#   Shapes: (2856, 2, 3000) (2856,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.52465931e-20 -4.18350972e-06 -8.64402936e-06]
#   ----------------------------------
#   Saved X_120.npy and y_120.npy
# Processing file 122/153: SC4631E0-PSG.edf
#   Shapes: (2758, 2, 3000) (2758,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [1.69406589e-21 4.99176742e-07 9.59109277e-07]
#   ----------------------------------
#   Saved X_121.npy and y_121.npy
# Processing file 123/153: SC4632E0-PSG.edf
#   Shapes: (2848, 2, 3000) (2848,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [8.47032947e-21 6.01015238e-06 2.35017397e-06]
#   ----------------------------------
#   Saved X_122.npy and y_122.npy
# Processing file 124/153: SC4641E0-PSG.edf
#   Shapes: (2680, 2, 3000) (2680,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [ 2.28698896e-20 -9.50910714e-07 -1.22901322e-05]
#   ----------------------------------
#   Saved X_123.npy and y_123.npy
# Processing file 125/153: SC4642E0-PSG.edf
#   Shapes: (2790, 2, 3000) (2790,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [ 1.35525272e-20 -2.60016960e-06 -4.14822721e-06]
#   ----------------------------------
#   Saved X_124.npy and y_124.npy
# Processing file 126/153: SC4651E0-PSG.edf
#   Shapes: (2860, 2, 3000) (2860,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [1.69406589e-20 4.10528455e-06 6.34990428e-06]
#   ----------------------------------
#   Saved X_125.npy and y_125.npy
# Processing file 127/153: SC4652E0-PSG.edf
#   Shapes: (2838, 2, 3000) (2838,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [3.38813179e-21 2.82976890e-05 3.22158262e-05]
#   ----------------------------------
#   Saved X_126.npy and y_126.npy
# Processing file 128/153: SC4661E0-PSG.edf
#   Shapes: (2664, 2, 3000) (2664,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.18584613e-20  7.53711346e-06  1.24612164e-05]
#   ----------------------------------
#   Saved X_127.npy and y_127.npy
# Processing file 129/153: SC4662E0-PSG.edf
#   Shapes: (2820, 2, 3000) (2820,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [1.01643954e-20 3.65549818e-06 6.71944771e-06]
#   ----------------------------------
#   Saved X_128.npy and y_128.npy
# Processing file 130/153: SC4671G0-PSG.edf
#   Shapes: (2780, 2, 3000) (2780,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [5.42101086e-20 1.52221322e-06 2.72368717e-06]
#   ----------------------------------
#   Saved X_129.npy and y_129.npy
# Processing file 131/153: SC4672G0-PSG.edf
#   Shapes: (2580, 2, 3000) (2580,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 1.69406589e-21 -6.29839209e-07 -9.21035554e-06]
#   ----------------------------------
#   Saved X_130.npy and y_130.npy
# Processing file 132/153: SC4701E0-PSG.edf
#   Shapes: (2679, 2, 3000) (2679,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 1.27054942e-21 -3.31990496e-05 -7.79833375e-06]
#   ----------------------------------
#   Saved X_131.npy and y_131.npy
# Processing file 133/153: SC4702E0-PSG.edf
#   Shapes: (2624, 2, 3000) (2624,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 1.52465931e-20 -6.02313733e-06 -4.21008695e-06]
#   ----------------------------------
#   Saved X_132.npy and y_132.npy
# Processing file 134/153: SC4711E0-PSG.edf
#   Shapes: (2730, 2, 3000) (2730,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [6.77626358e-21 8.04372303e-06 1.30578571e-06]
#   ----------------------------------
#   Saved X_133.npy and y_133.npy
# Processing file 135/153: SC4712E0-PSG.edf
#   Shapes: (2820, 2, 3000) (2820,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [-3.38813179e-21 -1.73193699e-06 -1.46230328e-06]
#   ----------------------------------
#   Saved X_134.npy and y_134.npy
# Processing file 136/153: SC4721E0-PSG.edf
#   Shapes: (2342, 2, 3000) (2342,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.18584613e-20 -4.15430410e-05  2.26440852e-06]
#   ----------------------------------
#   Saved X_135.npy and y_135.npy
# Processing file 137/153: SC4722E0-PSG.edf
#   Shapes: (2746, 2, 3000) (2746,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [ 8.47032947e-21 -4.81942361e-06  1.60109971e-06]
#   ----------------------------------
#   Saved X_136.npy and y_136.npy
# Processing file 138/153: SC4731E0-PSG.edf
#   Shapes: (2780, 2, 3000) (2780,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [8.47032947e-22 7.63480690e-07 1.35603357e-06]
#   ----------------------------------
#   Saved X_137.npy and y_137.npy
# Processing file 139/153: SC4732E0-PSG.edf
#   Shapes: (2519, 2, 3000) (2519,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [-6.77626358e-21 -2.81530110e-06 -8.53510298e-06]
#   ----------------------------------
#   Saved X_138.npy and y_138.npy
# Processing file 140/153: SC4741E0-PSG.edf
#   Shapes: (2689, 2, 3000) (2689,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [-2.54109884e-21  6.58415344e-06  2.10001469e-05]
#   ----------------------------------
#   Saved X_139.npy and y_139.npy
# Processing file 141/153: SC4742E0-PSG.edf
#   Shapes: (2650, 2, 3000) (2650,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [-6.77626358e-21  7.49599945e-06  1.43839981e-05]
#   ----------------------------------
#   Saved X_140.npy and y_140.npy
# Processing file 142/153: SC4751E0-PSG.edf
#   Shapes: (2680, 2, 3000) (2680,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [-9.31736242e-21  3.18544010e-06 -5.47249641e-06]
#   ----------------------------------
#   Saved X_141.npy and y_141.npy
# Processing file 143/153: SC4752E0-PSG.edf
#   Shapes: (2470, 2, 3000) (2470,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [1.01643954e-20 6.23892229e-06 2.32506370e-05]
#   ----------------------------------
#   Saved X_142.npy and y_142.npy
# Processing file 144/153: SC4761E0-PSG.edf
#   Shapes: (2610, 2, 3000) (2610,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [2.32934060e-20 3.27369746e-06 1.36092297e-05]
#   ----------------------------------
#   Saved X_143.npy and y_143.npy
# Processing file 145/153: SC4762E0-PSG.edf
#   Shapes: (2662, 2, 3000) (2662,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 4]
#   First label: 0
#   First epoch (first 3 samples): [2.03287907e-20 1.25881455e-05 9.45271187e-06]
#   ----------------------------------
#   Saved X_144.npy and y_144.npy
# Processing file 146/153: SC4771G0-PSG.edf
#   Shapes: (2756, 2, 3000) (2756,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.43995601e-20  6.03496268e-05  8.09026185e-05]
#   ----------------------------------
#   Saved X_145.npy and y_145.npy
# Processing file 147/153: SC4772G0-PSG.edf
#   Shapes: (2242, 2, 3000) (2242,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 5.08219768e-21 -6.28322719e-05 -5.53395341e-05]
#   ----------------------------------
#   Saved X_146.npy and y_146.npy
# Processing file 148/153: SC4801G0-PSG.edf
#   Shapes: (2774, 2, 3000) (2774,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 2.11758237e-21  3.99612237e-06 -6.67389019e-07]
#   ----------------------------------
#   Saved X_147.npy and y_147.npy
# Processing file 149/153: SC4802G0-PSG.edf
#   Shapes: (2810, 2, 3000) (2810,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.27054942e-20 -1.96170232e-06 -1.03765581e-06]
#   ----------------------------------
#   Saved X_148.npy and y_148.npy
# Processing file 150/153: SC4811G0-PSG.edf
#   Shapes: (2402, 2, 3000) (2402,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 2.71050543e-20 -2.43957048e-06  1.37564942e-05]
#   ----------------------------------
#   Saved X_149.npy and y_149.npy
# Processing file 151/153: SC4812G0-PSG.edf
#   Shapes: (2414, 2, 3000) (2414,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 1.01643954e-20 -5.29767750e-06 -3.06187126e-06]
#   ----------------------------------
#   Saved X_150.npy and y_150.npy
# Processing file 152/153: SC4821G0-PSG.edf
#   Shapes: (2721, 2, 3000) (2721,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [-1.82112084e-20  5.93712837e-06  9.50249878e-07]
#   ----------------------------------
#   Saved X_151.npy and y_151.npy
# Processing file 153/153: SC4822G0-PSG.edf
#   Shapes: (2810, 2, 3000) (2810,)
#   Channels: 2
#   Samples per epoch: 3000
#   Unique labels: [0 1 2 3 4]
#   First label: 0
#   First epoch (first 3 samples): [ 0.00000000e+00 -5.65870506e-08  3.47254628e-06]
#   ----------------------------------
#   Saved X_152.npy and y_152.npy

# %% [markdown]
# # Combine data for each subject

# %%
save_dir = "/content/processed_sc"
os.makedirs(save_dir, exist_ok=True)

files = sorted(os.listdir(save_dir))

X_list = []
y_list = []

for f in files:
    if f.startswith("X_"):
        X_list.append(np.load(os.path.join(save_dir, f)))
    if f.startswith("y_"):
        y_list.append(np.load(os.path.join(save_dir, f)))

X = np.vstack(X_list)
y = np.hstack(y_list)

# %% [markdown]
# # Print data summary + save data

# %%
print("===== FINAL DATASET SUMMARY (from memmap) =====")
print("X_mm shape:", X.shape)
print("y_mm shape:", y.shape)
print("Channels used:", X.shape[1])
print("Samples per epoch:", X.shape[2])

print("\nLabel distribution:")
unique, counts = np.unique(y, return_counts=True)
for u, c in zip(unique, counts):
    print(f"  Stage {u}: {c} epochs")
# Out:
# ===== FINAL DATASET SUMMARY (from memmap) =====
# X_mm shape: (414961, 2, 3000)
# y_mm shape: (414961,)
# Channels used: 2
# Samples per epoch: 3000
#
# Label distribution:
#   Stage 0: 285433 epochs
#   Stage 1: 21522 epochs
#   Stage 2: 69132 epochs
#   Stage 3: 13039 epochs
#   Stage 4: 25835 epochs

# %%
data_dir = "/preprocessed_data/"

np.save(data_dir + "/X.npy", X)
np.save(data_dir + "/y.npy", y)
